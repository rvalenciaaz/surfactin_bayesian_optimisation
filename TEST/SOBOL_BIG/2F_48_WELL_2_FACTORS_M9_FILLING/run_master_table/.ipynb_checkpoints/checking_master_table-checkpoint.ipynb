# %%
import pandas as pd

# %%
df=pd.read_csv("0_master_table.csv")

# %%
df.sort_values("sample")
# Out:
#    well_position  sample replicate  Glucose  NH4Cl  MgSO4  KH2PO4  Na2HPO4  \
# 18            B3     0_1     0_1_3       80     80     80      80       80
# 24            F2     0_1     0_1_1       80     80     80      80       80
# 3             C7     0_1     0_1_4       80     80     80      80       80
# 28            E5     0_1     0_1_2       80     80     80      80       80
# 35            B7     0_2     0_2_4       80     80     80      80       80
# 12            A4     0_2     0_2_3       80     80     80      80       80
# 19            F5     0_2     0_2_2       80     80     80      80       80
# 10            E3     0_2     0_2_1       80     80     80      80       80
# 6             F3     0_3     0_3_1       80     80     80      80       80
# 11            B2     0_3     0_3_3       80     80     80      80       80
# 4             A6     0_3     0_3_4       80     80     80      80       80
# ...
